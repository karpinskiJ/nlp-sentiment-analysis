# %%
import pandas as pd
import re
import numpy as np
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
    
class LSTMModel(nn.Module):
    def __init__(self,vocab_size ,embedding_dim, lstm_hidden_dim, output_dim, dropout_prob=0.2):
        super(LSTMModel, self).__init__()
        self.linear = nn.Linear(vocab_size, embedding_dim)
    
        self.lstm = nn.LSTM(embedding_dim, lstm_hidden_dim,dropout=dropout_prob, batch_first=True)
    
        self.fc = nn.Linear(lstm_hidden_dim, output_dim)

    def forward(self, x):
        embedded = self.linear(x)
        
        lstm_out, _ = self.lstm(embedded)
        lstm_out = lstm_out
        output = self.fc(lstm_out)
        return output

# %%
input_data_size = 1600000
data_path = "/kaggle/input/input-data-twitter/cleaned_data.csv"
df = pd.read_csv(data_path).dropna().sample(input_data_size)

# %%
import random
 # drop rows with missing values
df = [[x[-1], 0 if x[0] == 0 else 1] for x in df.values.tolist()] # convert the labels from 0 and 4 to 0 and 1
random.shuffle(df)
split_idx = int(len(df) * 0.8)  # index of element around ~ the first 80% of data

train_set, test_set = df[:split_idx], df[split_idx:] # training: 80% of data, validation: 20% of data

# %%
stop_words= "english"
max_word_freq_pct = 0.9 # 0.9
min_word_freq_cnt = 2 # 2
max_features = None

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow_vectorizer = CountVectorizer(max_df=max_word_freq_pct, min_df=min_word_freq_cnt, max_features=max_features, stop_words=stop_words)
bow_vectorizer.fit([x[0] for x in train_set])
# Out:
# CountVectorizer(max_df=0.9, min_df=2, stop_words='english')

# %%
vocab_size = len(bow_vectorizer.vocabulary_)

# %%
device = torch.device("cuda") 
vectorizer = bow_vectorizer

# %%
X_train_vectorized =  vectorizer.transform([x[0] for x in train_set])
X_test_vectorized = vectorizer.transform([x[0] for x in test_set])
# torch.tensor(vectorizer.transform([x[0] for x in test_set]).toarray(), dtype=torch.float32)

# %%
class TwitterDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return torch.tensor(self.X[idx].toarray()[0], dtype=torch.float32), self.y[idx]

# %%
embedding_dim = 128
hidden_dim = 100
output_dim = 2
dropout = 0.2
learning_rate = 0.01
epochs = 100
batch_size = 128

model = LSTMModel(vocab_size,embedding_dim, hidden_dim, output_dim, dropout).to(device)
optimizer = optim.Adam(model.parameters(),lr=learning_rate)
criterion = nn.CrossEntropyLoss()

y_train = [x[1] for x in train_set]
y_test = [x[1] for x in test_set] 

y_train = torch.tensor(y_train, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)
train_dataset = TwitterDataset(X_train_vectorized, y_train)
test_dataset = TwitterDataset(X_test_vectorized, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py:88: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
import wandb
wandb.login(key="2fff0adbd8c9e77982d937a66b6de880392e9e92")
# Out:
# wandb: Currently logged in as: karpinski-j (karpinski-gsn). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
import wandb
from datetime import datetime
run_name = datetime.today().strftime('%d%m%y%H%M%S')
wandb_run = wandb.init(
    project="nlp-sentiement-analysis",
    name=run_name,
    config={
        "learning_rate": learning_rate,
        "architecture": "LSTM",
        "dataset": "Twitter Sentiment Analysis",
        "epochs": epochs,
        "train_size": len(train_loader),
        "test_size": len(test_loader),
        "batch_size": batch_size,
        "embedding_dim": embedding_dim,
        "hidden_dim": hidden_dim,
        "dropout": dropout,
        "vectorizer": vectorizer.__class__.__name__,
        "input_data_size": input_data_size,
        "vocab_size": vocab_size

    }
)
# Out:
# Tracking run with wandb version 0.19.1
# Run data is saved locally in <code>/kaggle/working/wandb/run-20250106_123703-xjz3psde</code>
# Syncing run <strong><a href='https://wandb.ai/karpinski-gsn/nlp-sentiement-analysis/runs/xjz3psde' target="_blank">060125123703</a></strong> to <a href='https://wandb.ai/karpinski-gsn/nlp-sentiement-analysis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/karpinski-gsn/nlp-sentiement-analysis' target="_blank">https://wandb.ai/karpinski-gsn/nlp-sentiement-analysis</a>
#  View run at <a href='https://wandb.ai/karpinski-gsn/nlp-sentiement-analysis/runs/xjz3psde' target="_blank">https://wandb.ai/karpinski-gsn/nlp-sentiement-analysis/runs/xjz3psde</a>

# %%
for epoch in range(epochs):
    # Training
    model.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for batch_idx, (inputs, labels) in enumerate(train_loader):

        inputs = inputs.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels) # input to the model
        loss.backward() # update weights based on loss
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        train_correct += (predicted == labels).sum().item()
        train_total += labels.size(0)
        if batch_idx % 100 == 9:  # Print every 10 batches
            train_loss_avg = train_loss / train_total
            train_acc_avg = train_correct / train_total
            print(f'Epoch [{epoch+1}/{epochs}], Step [{batch_idx+1}/{len(train_loader)}], Train Loss: {train_loss_avg:.4f}, Train Acc: {train_acc_avg:.4f}')        
        
    steps_cnt = len(train_loader)
    train_loss_avg = train_loss / train_total
    train_acc_avg = train_correct / train_total

    

    # Validation, we have to use "eval" so that the dropout isn't added
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    all_predictions = []
    all_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            val_loss += loss.item() 
            _, predicted = torch.max(outputs, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            val_correct += (predicted == labels).sum().item()
            val_total += labels.size(0)

    # Print validation loss and accuracy after each epoch
    val_loss_avg = val_loss / len(test_loader)
    val_acc_avg = val_correct / val_total
    precision = precision_score(all_labels, all_predictions, average='weighted')
    recall = recall_score(all_labels, all_predictions, average='weighted')
    f1 = f1_score(all_labels, all_predictions, average='weighted')
    print(f'Epoch [{epoch+1}/{epochs}], Val Loss: {val_loss_avg:.4f}, Val Acc: {val_acc_avg:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}')
    wandb_run.log({
            f"epoch": epoch,
            f"train_loss": train_loss_avg,
            f"val_loss": val_loss_avg,
            f"val_accuracy": val_acc_avg,
            f"train_accuracy":train_acc_avg,
            f"precision": precision,
            f"recall": recall,
            f"f1": f1
    

    })

torch.save(model.state_dict(), "./data/model.pth")
artifact = wandb.Artifact(run_name, type='model')
artifact.add_file("./data/model.pth")
wandb_run.log_artifact(artifact)
wandb_run.finish()
# Out:
# Epoch [1/100], Step [10/10000], Train Loss: 0.6809, Train Acc: 0.5734
# Epoch [1/100], Step [110/10000], Train Loss: 0.5847, Train Acc: 0.6903
# Epoch [1/100], Step [210/10000], Train Loss: 0.5643, Train Acc: 0.7111
# Epoch [1/100], Step [310/10000], Train Loss: 0.5500, Train Acc: 0.7217
# Epoch [1/100], Step [410/10000], Train Loss: 0.5431, Train Acc: 0.7272
# Epoch [1/100], Step [510/10000], Train Loss: 0.5389, Train Acc: 0.7298
# Epoch [1/100], Step [610/10000], Train Loss: 0.5358, Train Acc: 0.7322
# Epoch [1/100], Step [710/10000], Train Loss: 0.5335, Train Acc: 0.7341
# Epoch [1/100], Step [810/10000], Train Loss: 0.5296, Train Acc: 0.7371
# Epoch [1/100], Step [910/10000], Train Loss: 0.5274, Train Acc: 0.7392
# Epoch [1/100], Step [1010/10000], Train Loss: 0.5261, Train Acc: 0.7403
# Epoch [1/100], Step [1110/10000], Train Loss: 0.5248, Train Acc: 0.7413
# Epoch [1/100], Step [1210/10000], Train Loss: 0.5233, Train Acc: 0.7418
# Epoch [1/100], Step [1310/10000], Train Loss: 0.5227, Train Acc: 0.7422
# Epoch [1/100], Step [1410/10000], Train Loss: 0.5211, Train Acc: 0.7437
# Epoch [1/100], Step [1510/10000], Train Loss: 0.5199, Train Acc: 0.7448
# Epoch [1/100], Step [1610/10000], Train Loss: 0.5189, Train Acc: 0.7454
# Epoch [1/100], Step [1710/10000], Train Loss: 0.5179, Train Acc: 0.7459
# Epoch [1/100], Step [1810/10000], Train Loss: 0.5170, Train Acc: 0.7467
# Epoch [1/100], Step [1910/10000], Train Loss: 0.5160, Train Acc: 0.7475
# Epoch [1/100], Step [2010/10000], Train Loss: 0.5149, Train Acc: 0.7482
# Epoch [1/100], Step [2110/10000], Train Loss: 0.5144, Train Acc: 0.7485
# Epoch [1/100], Step [2210/10000], Train Loss: 0.5136, Train Acc: 0.7488
# Epoch [1/100], Step [2310/10000], Train Loss: 0.5128, Train Acc: 0.7492
# Epoch [1/100], Step [2410/10000], Train Loss: 0.5122, Train Acc: 0.7497
# Epoch [1/100], Step [2510/10000], Train Loss: 0.5115, Train Acc: 0.7501
# Epoch [1/100], Step [2610/10000], Train Loss: 0.5108, Train Acc: 0.7505
# Epoch [1/100], Step [2710/10000], Train Loss: 0.5104, Train Acc: 0.7508
# Epoch [1/100], Step [2810/10000], Train Loss: 0.5099, Train Acc: 0.7513
# Epoch [1/100], Step [2910/10000], Train Loss: 0.5091, Train Acc: 0.7517
# Epoch [1/100], Step [3010/10000], Train Loss: 0.5086, Train Acc: 0.7520
# Epoch [1/100], Step [3110/10000], Train Loss: 0.5082, Train Acc: 0.7524
# Epoch [1/100], Step [3210/10000], Train Loss: 0.5080, Train Acc: 0.7526
# Epoch [1/100], Step [3310/10000], Train Loss: 0.5073, Train Acc: 0.7531
# Epoch [1/100], Step [3410/10000], Train Loss: 0.5070, Train Acc: 0.7532
# Epoch [1/100], Step [3510/10000], Train Loss: 0.5064, Train Acc: 0.7535
# Epoch [1/100], Step [3610/10000], Train Loss: 0.5060, Train Acc: 0.7537
# Epoch [1/100], Step [3710/10000], Train Loss: 0.5056, Train Acc: 0.7539
# Epoch [1/100], Step [3810/10000], Train Loss: 0.5053, Train Acc: 0.7543
# Epoch [1/100], Step [3910/10000], Train Loss: 0.5050, Train Acc: 0.7544
# Epoch [1/100], Step [4010/10000], Train Loss: 0.5048, Train Acc: 0.7546
# Epoch [1/100], Step [4110/10000], Train Loss: 0.5047, Train Acc: 0.7546
# Epoch [1/100], Step [4210/10000], Train Loss: 0.5043, Train Acc: 0.7548
# Epoch [1/100], Step [4310/10000], Train Loss: 0.5041, Train Acc: 0.7550
# Epoch [1/100], Step [4410/10000], Train Loss: 0.5039, Train Acc: 0.7551
# Epoch [1/100], Step [4510/10000], Train Loss: 0.5037, Train Acc: 0.7552
# Epoch [1/100], Step [4610/10000], Train Loss: 0.5036, Train Acc: 0.7554
# Epoch [1/100], Step [4710/10000], Train Loss: 0.5033, Train Acc: 0.7556
# Epoch [1/100], Step [4810/10000], Train Loss: 0.5032, Train Acc: 0.7557
# Epoch [1/100], Step [4910/10000], Train Loss: 0.5031, Train Acc: 0.7558
# Epoch [1/100], Step [5010/10000], Train Loss: 0.5027, Train Acc: 0.7560
# Epoch [1/100], Step [5110/10000], Train Loss: 0.5025, Train Acc: 0.7561
# Epoch [1/100], Step [5210/10000], Train Loss: 0.5022, Train Acc: 0.7563
# Epoch [1/100], Step [5310/10000], Train Loss: 0.5019, Train Acc: 0.7565
# Epoch [1/100], Step [5410/10000], Train Loss: 0.5018, Train Acc: 0.7566
# Epoch [1/100], Step [5510/10000], Train Loss: 0.5017, Train Acc: 0.7566
# Epoch [1/100], Step [5610/10000], Train Loss: 0.5014, Train Acc: 0.7568
# Epoch [1/100], Step [5710/10000], Train Loss: 0.5012, Train Acc: 0.7569
# Epoch [1/100], Step [5810/10000], Train Loss: 0.5009, Train Acc: 0.7571
# Epoch [1/100], Step [5910/10000], Train Loss: 0.5008, Train Acc: 0.7572
# Epoch [1/100], Step [6010/10000], Train Loss: 0.5005, Train Acc: 0.7573
# Epoch [1/100], Step [6110/10000], Train Loss: 0.5003, Train Acc: 0.7574
# Epoch [1/100], Step [6210/10000], Train Loss: 0.5002, Train Acc: 0.7575
# Epoch [1/100], Step [6310/10000], Train Loss: 0.5001, Train Acc: 0.7576
# Epoch [1/100], Step [6410/10000], Train Loss: 0.5000, Train Acc: 0.7576
# Epoch [1/100], Step [6510/10000], Train Loss: 0.4997, Train Acc: 0.7578
# Epoch [1/100], Step [6610/10000], Train Loss: 0.4996, Train Acc: 0.7579
# Epoch [1/100], Step [6710/10000], Train Loss: 0.4993, Train Acc: 0.7580
# Epoch [1/100], Step [6810/10000], Train Loss: 0.4993, Train Acc: 0.7581
# Epoch [1/100], Step [6910/10000], Train Loss: 0.4990, Train Acc: 0.7582
# Epoch [1/100], Step [7010/10000], Train Loss: 0.4989, Train Acc: 0.7583
# Epoch [1/100], Step [7110/10000], Train Loss: 0.4988, Train Acc: 0.7583
# Epoch [1/100], Step [7210/10000], Train Loss: 0.4987, Train Acc: 0.7584
# Epoch [1/100], Step [7310/10000], Train Loss: 0.4986, Train Acc: 0.7585
# Epoch [1/100], Step [7410/10000], Train Loss: 0.4984, Train Acc: 0.7586
# Epoch [1/100], Step [7510/10000], Train Loss: 0.4984, Train Acc: 0.7586
# Epoch [1/100], Step [7610/10000], Train Loss: 0.4982, Train Acc: 0.7587
# Epoch [1/100], Step [7710/10000], Train Loss: 0.4980, Train Acc: 0.7588
# Epoch [1/100], Step [7810/10000], Train Loss: 0.4979, Train Acc: 0.7588
# Epoch [3/100], Step [1910/10000], Train Loss: 0.4658, Train Acc: 0.7805
# Epoch [3/100], Step [2010/10000], Train Loss: 0.4661, Train Acc: 0.7805
# Epoch [3/100], Step [2110/10000], Train Loss: 0.4660, Train Acc: 0.7807
# Epoch [3/100], Step [2210/10000], Train Loss: 0.4662, Train Acc: 0.7806
# Epoch [3/100], Step [2310/10000], Train Loss: 0.4661, Train Acc: 0.7807
# Epoch [3/100], Step [2410/10000], Train Loss: 0.4662, Train Acc: 0.7808
# Epoch [3/100], Step [2510/10000], Train Loss: 0.4664, Train Acc: 0.7807
# Epoch [3/100], Step [2610/10000], Train Loss: 0.4666, Train Acc: 0.7808
# Epoch [3/100], Step [2710/10000], Train Loss: 0.4664, Train Acc: 0.7809
# Epoch [3/100], Step [2810/10000], Train Loss: 0.4662, Train Acc: 0.7809
# Epoch [3/100], Step [2910/10000], Train Loss: 0.4663, Train Acc: 0.7809
# Epoch [3/100], Step [3010/10000], Train Loss: 0.4663, Train Acc: 0.7809
# Epoch [3/100], Step [3110/10000], Train Loss: 0.4664, Train Acc: 0.7808
# Epoch [3/100], Step [3210/10000], Train Loss: 0.4662, Train Acc: 0.7808
# Epoch [3/100], Step [3310/10000], Train Loss: 0.4662, Train Acc: 0.7808
# Epoch [3/100], Step [3410/10000], Train Loss: 0.4662, Train Acc: 0.7810
# Epoch [3/100], Step [3510/10000], Train Loss: 0.4664, Train Acc: 0.7808
# Epoch [3/100], Step [3610/10000], Train Loss: 0.4661, Train Acc: 0.7810
# Epoch [3/100], Step [3710/10000], Train Loss: 0.4660, Train Acc: 0.7811
# Epoch [3/100], Step [3810/10000], Train Loss: 0.4660, Train Acc: 0.7812
# Epoch [3/100], Step [3910/10000], Train Loss: 0.4662, Train Acc: 0.7810
# Epoch [3/100], Step [4010/10000], Train Loss: 0.4662, Train Acc: 0.7811
# Epoch [3/100], Step [4110/10000], Train Loss: 0.4663, Train Acc: 0.7810
# Epoch [3/100], Step [4210/10000], Train Loss: 0.4663, Train Acc: 0.7809
# Epoch [3/100], Step [4310/10000], Train Loss: 0.4663, Train Acc: 0.7809
# Epoch [3/100], Step [4410/10000], Train Loss: 0.4664, Train Acc: 0.7809
# Epoch [3/100], Step [4510/10000], Train Loss: 0.4663, Train Acc: 0.7810
# Epoch [3/100], Step [4610/10000], Train Loss: 0.4665, Train Acc: 0.7809
# Epoch [3/100], Step [4710/10000], Train Loss: 0.4665, Train Acc: 0.7809
# Epoch [3/100], Step [4810/10000], Train Loss: 0.4665, Train Acc: 0.7809
# Epoch [3/100], Step [4910/10000], Train Loss: 0.4666, Train Acc: 0.7809
# Epoch [3/100], Step [5010/10000], Train Loss: 0.4666, Train Acc: 0.7809
# Epoch [3/100], Step [5110/10000], Train Loss: 0.4668, Train Acc: 0.7809
# Epoch [3/100], Step [5210/10000], Train Loss: 0.4668, Train Acc: 0.7808
# Epoch [3/100], Step [5310/10000], Train Loss: 0.4670, Train Acc: 0.7807
# Epoch [3/100], Step [5410/10000], Train Loss: 0.4669, Train Acc: 0.7808
# Epoch [3/100], Step [5510/10000], Train Loss: 0.4670, Train Acc: 0.7807
# Epoch [3/100], Step [5610/10000], Train Loss: 0.4671, Train Acc: 0.7807
# Epoch [3/100], Step [5710/10000], Train Loss: 0.4670, Train Acc: 0.7808
# Epoch [3/100], Step [5810/10000], Train Loss: 0.4671, Train Acc: 0.7807
# Epoch [3/100], Step [5910/10000], Train Loss: 0.4671, Train Acc: 0.7807
# Epoch [3/100], Step [6010/10000], Train Loss: 0.4672, Train Acc: 0.7807
# Epoch [3/100], Step [6110/10000], Train Loss: 0.4673, Train Acc: 0.7806
# Epoch [3/100], Step [6210/10000], Train Loss: 0.4672, Train Acc: 0.7805
# Epoch [3/100], Step [6310/10000], Train Loss: 0.4673, Train Acc: 0.7804
# Epoch [3/100], Step [6410/10000], Train Loss: 0.4675, Train Acc: 0.7804
# Epoch [3/100], Step [6510/10000], Train Loss: 0.4675, Train Acc: 0.7804
# Epoch [3/100], Step [6610/10000], Train Loss: 0.4674, Train Acc: 0.7804
# Epoch [3/100], Step [6710/10000], Train Loss: 0.4674, Train Acc: 0.7804
# Epoch [3/100], Step [6810/10000], Train Loss: 0.4674, Train Acc: 0.7805
# Epoch [3/100], Step [6910/10000], Train Loss: 0.4674, Train Acc: 0.7805
# Epoch [3/100], Step [7010/10000], Train Loss: 0.4675, Train Acc: 0.7804
# Epoch [3/100], Step [7110/10000], Train Loss: 0.4676, Train Acc: 0.7803
# Epoch [3/100], Step [7210/10000], Train Loss: 0.4675, Train Acc: 0.7804
# Epoch [3/100], Step [7310/10000], Train Loss: 0.4674, Train Acc: 0.7805
# Epoch [3/100], Step [7410/10000], Train Loss: 0.4674, Train Acc: 0.7805
# Epoch [3/100], Step [7510/10000], Train Loss: 0.4675, Train Acc: 0.7804
# Epoch [3/100], Step [7610/10000], Train Loss: 0.4675, Train Acc: 0.7803
# Epoch [3/100], Step [7710/10000], Train Loss: 0.4675, Train Acc: 0.7803
# Epoch [3/100], Step [7810/10000], Train Loss: 0.4676, Train Acc: 0.7803
# Epoch [3/100], Step [7910/10000], Train Loss: 0.4677, Train Acc: 0.7802
# Epoch [3/100], Step [8010/10000], Train Loss: 0.4677, Train Acc: 0.7802
# Epoch [3/100], Step [8110/10000], Train Loss: 0.4678, Train Acc: 0.7802
# Epoch [3/100], Step [8210/10000], Train Loss: 0.4678, Train Acc: 0.7802
# Epoch [3/100], Step [8310/10000], Train Loss: 0.4678, Train Acc: 0.7802
# Epoch [3/100], Step [8410/10000], Train Loss: 0.4679, Train Acc: 0.7801
# Epoch [3/100], Step [8510/10000], Train Loss: 0.4680, Train Acc: 0.7801
# Epoch [3/100], Step [8610/10000], Train Loss: 0.4679, Train Acc: 0.7801
# Epoch [3/100], Step [8710/10000], Train Loss: 0.4681, Train Acc: 0.7801
# Epoch [3/100], Step [8810/10000], Train Loss: 0.4681, Train Acc: 0.7801
# Epoch [3/100], Step [8910/10000], Train Loss: 0.4682, Train Acc: 0.7800
# Epoch [3/100], Step [9010/10000], Train Loss: 0.4683, Train Acc: 0.7800
# Epoch [3/100], Step [9110/10000], Train Loss: 0.4683, Train Acc: 0.7799
# Epoch [3/100], Step [9210/10000], Train Loss: 0.4683, Train Acc: 0.7799
# Epoch [3/100], Step [9310/10000], Train Loss: 0.4683, Train Acc: 0.7799
# Epoch [3/100], Step [9410/10000], Train Loss: 0.4683, Train Acc: 0.7800
# Epoch [3/100], Step [9510/10000], Train Loss: 0.4683, Train Acc: 0.7799
# Epoch [3/100], Step [9610/10000], Train Loss: 0.4684, Train Acc: 0.7799
# Epoch [3/100], Step [9710/10000], Train Loss: 0.4685, Train Acc: 0.7798
# Epoch [3/100], Step [9810/10000], Train Loss: 0.4685, Train Acc: 0.7798
# Epoch [3/100], Step [9910/10000], Train Loss: 0.4685, Train Acc: 0.7798
# Epoch [3/100], Val Loss: 0.4890, Val Acc: 0.7697, Precision: 0.7698, Recall: 0.7697, F1: 0.7697
# Epoch [4/100], Step [10/10000], Train Loss: 0.4745, Train Acc: 0.7797
# Epoch [4/100], Step [110/10000], Train Loss: 0.4665, Train Acc: 0.7826
# Epoch [4/100], Step [210/10000], Train Loss: 0.4621, Train Acc: 0.7847
# Epoch [4/100], Step [310/10000], Train Loss: 0.4618, Train Acc: 0.7850
# Epoch [4/100], Step [410/10000], Train Loss: 0.4619, Train Acc: 0.7846
# Epoch [4/100], Step [510/10000], Train Loss: 0.4613, Train Acc: 0.7850
# Epoch [4/100], Step [610/10000], Train Loss: 0.4607, Train Acc: 0.7851
# Epoch [4/100], Step [710/10000], Train Loss: 0.4618, Train Acc: 0.7846
# Epoch [4/100], Step [810/10000], Train Loss: 0.4620, Train Acc: 0.7847
# Epoch [4/100], Step [910/10000], Train Loss: 0.4619, Train Acc: 0.7847
# Epoch [4/100], Step [1010/10000], Train Loss: 0.4623, Train Acc: 0.7844
# Epoch [4/100], Step [1110/10000], Train Loss: 0.4624, Train Acc: 0.7842
# Epoch [4/100], Step [1210/10000], Train Loss: 0.4629, Train Acc: 0.7837
# Epoch [4/100], Step [1310/10000], Train Loss: 0.4624, Train Acc: 0.7839
# Epoch [4/100], Step [1410/10000], Train Loss: 0.4624, Train Acc: 0.7835
# Epoch [4/100], Step [1510/10000], Train Loss: 0.4622, Train Acc: 0.7834
# Epoch [4/100], Step [1610/10000], Train Loss: 0.4625, Train Acc: 0.7832
# Epoch [4/100], Step [1710/10000], Train Loss: 0.4625, Train Acc: 0.7833
# Epoch [4/100], Step [1810/10000], Train Loss: 0.4622, Train Acc: 0.7834
# Epoch [4/100], Step [1910/10000], Train Loss: 0.4624, Train Acc: 0.7834
# Epoch [4/100], Step [2010/10000], Train Loss: 0.4625, Train Acc: 0.7832
# Epoch [4/100], Step [2110/10000], Train Loss: 0.4622, Train Acc: 0.7833
# Epoch [4/100], Step [2210/10000], Train Loss: 0.4621, Train Acc: 0.7833
# Epoch [4/100], Step [2310/10000], Train Loss: 0.4625, Train Acc: 0.7831
# Epoch [4/100], Step [2410/10000], Train Loss: 0.4625, Train Acc: 0.7831
# Epoch [4/100], Step [2510/10000], Train Loss: 0.4631, Train Acc: 0.7829
# Epoch [4/100], Step [2610/10000], Train Loss: 0.4633, Train Acc: 0.7827
# Epoch [4/100], Step [2710/10000], Train Loss: 0.4634, Train Acc: 0.7827
# Epoch [4/100], Step [2810/10000], Train Loss: 0.4635, Train Acc: 0.7827
# Epoch [4/100], Step [2910/10000], Train Loss: 0.4634, Train Acc: 0.7828
# Epoch [4/100], Step [3010/10000], Train Loss: 0.4632, Train Acc: 0.7828
# Epoch [4/100], Step [3110/10000], Train Loss: 0.4631, Train Acc: 0.7829
# Epoch [4/100], Step [3210/10000], Train Loss: 0.4634, Train Acc: 0.7827
# Epoch [4/100], Step [3310/10000], Train Loss: 0.4637, Train Acc: 0.7824
# Epoch [4/100], Step [3410/10000], Train Loss: 0.4637, Train Acc: 0.7826
# Epoch [4/100], Step [3510/10000], Train Loss: 0.4638, Train Acc: 0.7824
# Epoch [4/100], Step [3610/10000], Train Loss: 0.4637, Train Acc: 0.7825
# Epoch [4/100], Step [3710/10000], Train Loss: 0.4639, Train Acc: 0.7824
# Epoch [4/100], Step [3810/10000], Train Loss: 0.4638, Train Acc: 0.7826
# Epoch [4/100], Step [3910/10000], Train Loss: 0.4637, Train Acc: 0.7826
# Epoch [4/100], Step [4010/10000], Train Loss: 0.4637, Train Acc: 0.7826
# Epoch [4/100], Step [4110/10000], Train Loss: 0.4638, Train Acc: 0.7825
# Epoch [4/100], Step [4210/10000], Train Loss: 0.4638, Train Acc: 0.7825
# Epoch [4/100], Step [4310/10000], Train Loss: 0.4638, Train Acc: 0.7826
# Epoch [4/100], Step [4410/10000], Train Loss: 0.4640, Train Acc: 0.7824
# Epoch [4/100], Step [4510/10000], Train Loss: 0.4640, Train Acc: 0.7825
# Epoch [4/100], Step [4610/10000], Train Loss: 0.4642, Train Acc: 0.7824
# Epoch [4/100], Step [4710/10000], Train Loss: 0.4641, Train Acc: 0.7825
# Epoch [4/100], Step [4810/10000], Train Loss: 0.4642, Train Acc: 0.7824
# Epoch [4/100], Step [4910/10000], Train Loss: 0.4643, Train Acc: 0.7823
# Epoch [4/100], Step [5010/10000], Train Loss: 0.4643, Train Acc: 0.7824
# Epoch [4/100], Step [5110/10000], Train Loss: 0.4644, Train Acc: 0.7822
# Epoch [4/100], Step [5210/10000], Train Loss: 0.4646, Train Acc: 0.7821
# Epoch [4/100], Step [5310/10000], Train Loss: 0.4647, Train Acc: 0.7820
# Epoch [4/100], Step [5410/10000], Train Loss: 0.4648, Train Acc: 0.7820
# Epoch [4/100], Step [5510/10000], Train Loss: 0.4647, Train Acc: 0.7820
# Epoch [4/100], Step [5610/10000], Train Loss: 0.4648, Train Acc: 0.7819
# Epoch [4/100], Step [5710/10000], Train Loss: 0.4647, Train Acc: 0.7821
# Epoch [4/100], Step [5810/10000], Train Loss: 0.4647, Train Acc: 0.7821
# Epoch [4/100], Step [5910/10000], Train Loss: 0.4648, Train Acc: 0.7821
# Epoch [4/100], Step [6010/10000], Train Loss: 0.4648, Train Acc: 0.7821
# Epoch [4/100], Step [6110/10000], Train Loss: 0.4648, Train Acc: 0.7820
# Epoch [4/100], Step [6210/10000], Train Loss: 0.4649, Train Acc: 0.7819
# Epoch [4/100], Step [6310/10000], Train Loss: 0.4649, Train Acc: 0.7820
# Epoch [4/100], Step [6410/10000], Train Loss: 0.4649, Train Acc: 0.7820
# Epoch [4/100], Step [6510/10000], Train Loss: 0.4649, Train Acc: 0.7819
# Epoch [4/100], Step [6610/10000], Train Loss: 0.4649, Train Acc: 0.7819
# Epoch [4/100], Step [6710/10000], Train Loss: 0.4649, Train Acc: 0.7819
# Epoch [4/100], Step [6810/10000], Train Loss: 0.4648, Train Acc: 0.7819
# Epoch [4/100], Step [6910/10000], Train Loss: 0.4649, Train Acc: 0.7819
# Epoch [4/100], Step [7010/10000], Train Loss: 0.4650, Train Acc: 0.7819
# Epoch [4/100], Step [7110/10000], Train Loss: 0.4650, Train Acc: 0.7819
# Epoch [4/100], Step [7210/10000], Train Loss: 0.4650, Train Acc: 0.7820
# Epoch [4/100], Step [7310/10000], Train Loss: 0.4651, Train Acc: 0.7819
# Epoch [4/100], Step [7410/10000], Train Loss: 0.4652, Train Acc: 0.7819
# Epoch [4/100], Step [7510/10000], Train Loss: 0.4652, Train Acc: 0.7819
# Epoch [4/100], Step [7610/10000], Train Loss: 0.4652, Train Acc: 0.7820
# Epoch [4/100], Step [7710/10000], Train Loss: 0.4651, Train Acc: 0.7820
# Epoch [4/100], Step [7810/10000], Train Loss: 0.4652, Train Acc: 0.7820
# Epoch [4/100], Step [7910/10000], Train Loss: 0.4652, Train Acc: 0.7820
# Epoch [4/100], Step [8010/10000], Train Loss: 0.4653, Train Acc: 0.7819
# Epoch [4/100], Step [8110/10000], Train Loss: 0.4652, Train Acc: 0.7819
# Epoch [4/100], Step [8210/10000], Train Loss: 0.4652, Train Acc: 0.7820
# Epoch [4/100], Step [8310/10000], Train Loss: 0.4652, Train Acc: 0.7820
# Epoch [4/100], Step [8410/10000], Train Loss: 0.4653, Train Acc: 0.7821
# Epoch [4/100], Step [8510/10000], Train Loss: 0.4653, Train Acc: 0.7820
# Epoch [4/100], Step [8610/10000], Train Loss: 0.4653, Train Acc: 0.7820
# Epoch [4/100], Step [8710/10000], Train Loss: 0.4653, Train Acc: 0.7820
# Epoch [4/100], Step [8810/10000], Train Loss: 0.4653, Train Acc: 0.7820
# Epoch [4/100], Step [8910/10000], Train Loss: 0.4654, Train Acc: 0.7819
# Epoch [4/100], Step [9010/10000], Train Loss: 0.4655, Train Acc: 0.7819
# Epoch [4/100], Step [9110/10000], Train Loss: 0.4655, Train Acc: 0.7819
# Epoch [4/100], Step [9210/10000], Train Loss: 0.4655, Train Acc: 0.7819
# Epoch [4/100], Step [9310/10000], Train Loss: 0.4655, Train Acc: 0.7819
# Epoch [4/100], Step [9410/10000], Train Loss: 0.4655, Train Acc: 0.7819
# Epoch [4/100], Step [9510/10000], Train Loss: 0.4656, Train Acc: 0.7819
# Epoch [4/100], Step [9610/10000], Train Loss: 0.4657, Train Acc: 0.7818
# Epoch [4/100], Step [9710/10000], Train Loss: 0.4657, Train Acc: 0.7818
# Epoch [4/100], Step [9810/10000], Train Loss: 0.4659, Train Acc: 0.7817
# Epoch [4/100], Step [9910/10000], Train Loss: 0.4660, Train Acc: 0.7817
# Epoch [4/100], Val Loss: 0.4941, Val Acc: 0.7661, Precision: 0.7708, Recall: 0.7661, F1: 0.7651
# Epoch [5/100], Step [10/10000], Train Loss: 0.4533, Train Acc: 0.7953
# Epoch [5/100], Step [110/10000], Train Loss: 0.4571, Train Acc: 0.7866
# Epoch [5/100], Step [210/10000], Train Loss: 0.4579, Train Acc: 0.7870
# Epoch [5/100], Step [310/10000], Train Loss: 0.4587, Train Acc: 0.7861
# Epoch [5/100], Step [410/10000], Train Loss: 0.4599, Train Acc: 0.7854
# Epoch [5/100], Step [510/10000], Train Loss: 0.4600, Train Acc: 0.7855
# Epoch [5/100], Step [610/10000], Train Loss: 0.4620, Train Acc: 0.7846
# Epoch [5/100], Step [710/10000], Train Loss: 0.4617, Train Acc: 0.7847
# Epoch [5/100], Step [810/10000], Train Loss: 0.4612, Train Acc: 0.7852
# Epoch [5/100], Step [910/10000], Train Loss: 0.4612, Train Acc: 0.7850
# Epoch [5/100], Step [1010/10000], Train Loss: 0.4604, Train Acc: 0.7852
# Epoch [5/100], Step [1110/10000], Train Loss: 0.4599, Train Acc: 0.7857
# Epoch [5/100], Step [1210/10000], Train Loss: 0.4597, Train Acc: 0.7860
# Epoch [5/100], Step [1310/10000], Train Loss: 0.4602, Train Acc: 0.7857
# Epoch [5/100], Step [1410/10000], Train Loss: 0.4602, Train Acc: 0.7856
# Epoch [5/100], Step [1510/10000], Train Loss: 0.4604, Train Acc: 0.7853
# Epoch [5/100], Step [1610/10000], Train Loss: 0.4607, Train Acc: 0.7850
# Epoch [5/100], Step [1710/10000], Train Loss: 0.4608, Train Acc: 0.7851
# Epoch [5/100], Step [1810/10000], Train Loss: 0.4608, Train Acc: 0.7852
# Epoch [5/100], Step [1910/10000], Train Loss: 0.4608, Train Acc: 0.7851
# Epoch [5/100], Step [2010/10000], Train Loss: 0.4612, Train Acc: 0.7850
# Epoch [5/100], Step [2110/10000], Train Loss: 0.4614, Train Acc: 0.7850
# Epoch [5/100], Step [2210/10000], Train Loss: 0.4617, Train Acc: 0.7848
# Epoch [5/100], Step [2310/10000], Train Loss: 0.4618, Train Acc: 0.7845
# Epoch [5/100], Step [2410/10000], Train Loss: 0.4622, Train Acc: 0.7842
# Epoch [5/100], Step [2510/10000], Train Loss: 0.4622, Train Acc: 0.7843
# Epoch [5/100], Step [2610/10000], Train Loss: 0.4621, Train Acc: 0.7844
# Epoch [5/100], Step [2710/10000], Train Loss: 0.4623, Train Acc: 0.7843
# Epoch [5/100], Step [2810/10000], Train Loss: 0.4621, Train Acc: 0.7842
# Epoch [5/100], Step [2910/10000], Train Loss: 0.4624, Train Acc: 0.7841
# Epoch [5/100], Step [3010/10000], Train Loss: 0.4625, Train Acc: 0.7841
# Epoch [5/100], Step [3110/10000], Train Loss: 0.4627, Train Acc: 0.7838
# Epoch [5/100], Step [3210/10000], Train Loss: 0.4628, Train Acc: 0.7836
# Epoch [5/100], Step [3310/10000], Train Loss: 0.4628, Train Acc: 0.7836
# Epoch [5/100], Step [3410/10000], Train Loss: 0.4629, Train Acc: 0.7835
# Epoch [5/100], Step [3510/10000], Train Loss: 0.4629, Train Acc: 0.7834
# Epoch [5/100], Step [3610/10000], Train Loss: 0.4629, Train Acc: 0.7834
# Epoch [5/100], Step [3710/10000], Train Loss: 0.4628, Train Acc: 0.7834
# Epoch [5/100], Step [3810/10000], Train Loss: 0.4630, Train Acc: 0.7833
# Epoch [5/100], Step [3910/10000], Train Loss: 0.4631, Train Acc: 0.7833
# Epoch [5/100], Step [4010/10000], Train Loss: 0.4633, Train Acc: 0.7831
# Epoch [5/100], Step [4110/10000], Train Loss: 0.4634, Train Acc: 0.7830
# Epoch [5/100], Step [4210/10000], Train Loss: 0.4636, Train Acc: 0.7830
# Epoch [5/100], Step [4310/10000], Train Loss: 0.4637, Train Acc: 0.7829
# Epoch [5/100], Step [4410/10000], Train Loss: 0.4636, Train Acc: 0.7829
# Epoch [5/100], Step [4510/10000], Train Loss: 0.4637, Train Acc: 0.7830
# Epoch [5/100], Step [4610/10000], Train Loss: 0.4636, Train Acc: 0.7830
# Epoch [5/100], Step [4710/10000], Train Loss: 0.4638, Train Acc: 0.7829
# Epoch [5/100], Step [4810/10000], Train Loss: 0.4638, Train Acc: 0.7829
# Epoch [5/100], Step [4910/10000], Train Loss: 0.4637, Train Acc: 0.7829
# Epoch [5/100], Step [5010/10000], Train Loss: 0.4636, Train Acc: 0.7830
# Epoch [5/100], Step [5110/10000], Train Loss: 0.4636, Train Acc: 0.7830
# Epoch [5/100], Step [5210/10000], Train Loss: 0.4637, Train Acc: 0.7829
# Epoch [5/100], Step [5310/10000], Train Loss: 0.4638, Train Acc: 0.7829
# Epoch [5/100], Step [5410/10000], Train Loss: 0.4637, Train Acc: 0.7829
# Epoch [5/100], Step [5510/10000], Train Loss: 0.4637, Train Acc: 0.7830
# Epoch [5/100], Step [5610/10000], Train Loss: 0.4637, Train Acc: 0.7829
# Epoch [5/100], Step [5710/10000], Train Loss: 0.4636, Train Acc: 0.7831
# Epoch [5/100], Step [5810/10000], Train Loss: 0.4636, Train Acc: 0.7830
# Epoch [5/100], Step [5910/10000], Train Loss: 0.4635, Train Acc: 0.7832
# Epoch [5/100], Step [6010/10000], Train Loss: 0.4634, Train Acc: 0.7832
# Epoch [5/100], Step [6110/10000], Train Loss: 0.4634, Train Acc: 0.7832
# Epoch [5/100], Step [6210/10000], Train Loss: 0.4635, Train Acc: 0.7832
# Epoch [5/100], Step [6310/10000], Train Loss: 0.4635, Train Acc: 0.7832
# Epoch [5/100], Step [6410/10000], Train Loss: 0.4635, Train Acc: 0.7832
# Epoch [5/100], Step [6510/10000], Train Loss: 0.4635, Train Acc: 0.7832
# Epoch [5/100], Step [6610/10000], Train Loss: 0.4635, Train Acc: 0.7831
# Epoch [5/100], Step [6710/10000], Train Loss: 0.4637, Train Acc: 0.7830
# Epoch [5/100], Step [6810/10000], Train Loss: 0.4638, Train Acc: 0.7830
# Epoch [5/100], Step [6910/10000], Train Loss: 0.4638, Train Acc: 0.7831
# Epoch [5/100], Step [7010/10000], Train Loss: 0.4638, Train Acc: 0.7830
# Epoch [5/100], Step [7110/10000], Train Loss: 0.4640, Train Acc: 0.7830
# Epoch [5/100], Step [7210/10000], Train Loss: 0.4639, Train Acc: 0.7830
# Epoch [5/100], Step [7310/10000], Train Loss: 0.4641, Train Acc: 0.7829
# Epoch [5/100], Step [7410/10000], Train Loss: 0.4643, Train Acc: 0.7828
# Epoch [5/100], Step [7510/10000], Train Loss: 0.4643, Train Acc: 0.7827
# Epoch [5/100], Step [7610/10000], Train Loss: 0.4644, Train Acc: 0.7827
# Epoch [5/100], Step [7710/10000], Train Loss: 0.4643, Train Acc: 0.7828
# Epoch [5/100], Step [7810/10000], Train Loss: 0.4643, Train Acc: 0.7828
# Epoch [5/100], Step [7910/10000], Train Loss: 0.4643, Train Acc: 0.7829
# Epoch [5/100], Step [8010/10000], Train Loss: 0.4644, Train Acc: 0.7829
# Epoch [5/100], Step [8110/10000], Train Loss: 0.4644, Train Acc: 0.7828
# Epoch [5/100], Step [8210/10000], Train Loss: 0.4645, Train Acc: 0.7828
# Epoch [5/100], Step [8310/10000], Train Loss: 0.4644, Train Acc: 0.7828
# Epoch [5/100], Step [8410/10000], Train Loss: 0.4644, Train Acc: 0.7829
# Epoch [5/100], Step [8510/10000], Train Loss: 0.4644, Train Acc: 0.7829
# Epoch [5/100], Step [8610/10000], Train Loss: 0.4645, Train Acc: 0.7828
# Epoch [5/100], Step [8710/10000], Train Loss: 0.4645, Train Acc: 0.7828
# Epoch [5/100], Step [8810/10000], Train Loss: 0.4644, Train Acc: 0.7829
# Epoch [5/100], Step [8910/10000], Train Loss: 0.4645, Train Acc: 0.7828
# Epoch [5/100], Step [9010/10000], Train Loss: 0.4645, Train Acc: 0.7827
# Epoch [5/100], Step [9110/10000], Train Loss: 0.4645, Train Acc: 0.7828
# Epoch [5/100], Step [9210/10000], Train Loss: 0.4644, Train Acc: 0.7828
# Epoch [5/100], Step [9310/10000], Train Loss: 0.4645, Train Acc: 0.7828
# Epoch [5/100], Step [9410/10000], Train Loss: 0.4645, Train Acc: 0.7827
# Epoch [5/100], Step [9510/10000], Train Loss: 0.4644, Train Acc: 0.7827
# Epoch [5/100], Step [9610/10000], Train Loss: 0.4644, Train Acc: 0.7828
# Epoch [5/100], Step [9710/10000], Train Loss: 0.4644, Train Acc: 0.7828
# Epoch [5/100], Step [9810/10000], Train Loss: 0.4643, Train Acc: 0.7828
# Epoch [5/100], Step [9910/10000], Train Loss: 0.4643, Train Acc: 0.7829
# Epoch [6/100], Step [3510/10000], Train Loss: 0.4613, Train Acc: 0.7857
# Epoch [6/100], Step [3610/10000], Train Loss: 0.4611, Train Acc: 0.7858
# Epoch [6/100], Step [3710/10000], Train Loss: 0.4611, Train Acc: 0.7858
# Epoch [6/100], Step [3810/10000], Train Loss: 0.4613, Train Acc: 0.7857
# Epoch [6/100], Step [3910/10000], Train Loss: 0.4613, Train Acc: 0.7857
# Epoch [6/100], Step [4010/10000], Train Loss: 0.4614, Train Acc: 0.7855
# Epoch [6/100], Step [4110/10000], Train Loss: 0.4613, Train Acc: 0.7856
# Epoch [6/100], Step [4210/10000], Train Loss: 0.4614, Train Acc: 0.7855
# Epoch [6/100], Step [4310/10000], Train Loss: 0.4615, Train Acc: 0.7854
# Epoch [6/100], Step [4410/10000], Train Loss: 0.4615, Train Acc: 0.7854
# Epoch [6/100], Step [4510/10000], Train Loss: 0.4615, Train Acc: 0.7853
# Epoch [6/100], Step [4610/10000], Train Loss: 0.4615, Train Acc: 0.7854
# Epoch [6/100], Step [4710/10000], Train Loss: 0.4616, Train Acc: 0.7853
# Epoch [6/100], Step [4810/10000], Train Loss: 0.4617, Train Acc: 0.7853
# Epoch [6/100], Step [4910/10000], Train Loss: 0.4618, Train Acc: 0.7852
# Epoch [6/100], Step [5010/10000], Train Loss: 0.4617, Train Acc: 0.7852
# Epoch [6/100], Step [5110/10000], Train Loss: 0.4617, Train Acc: 0.7853
# Epoch [6/100], Step [5210/10000], Train Loss: 0.4617, Train Acc: 0.7853
# Epoch [6/100], Step [5310/10000], Train Loss: 0.4619, Train Acc: 0.7852
# Epoch [6/100], Step [5410/10000], Train Loss: 0.4621, Train Acc: 0.7851
# Epoch [6/100], Step [5510/10000], Train Loss: 0.4618, Train Acc: 0.7853
# Epoch [6/100], Step [5610/10000], Train Loss: 0.4621, Train Acc: 0.7851
# Epoch [6/100], Step [5710/10000], Train Loss: 0.4622, Train Acc: 0.7850
# Epoch [6/100], Step [5810/10000], Train Loss: 0.4622, Train Acc: 0.7851
# Epoch [6/100], Step [5910/10000], Train Loss: 0.4624, Train Acc: 0.7850
# Epoch [6/100], Step [6010/10000], Train Loss: 0.4623, Train Acc: 0.7851
# Epoch [6/100], Step [6110/10000], Train Loss: 0.4622, Train Acc: 0.7850
# Epoch [6/100], Step [6210/10000], Train Loss: 0.4623, Train Acc: 0.7850
# Epoch [6/100], Step [6310/10000], Train Loss: 0.4624, Train Acc: 0.7849
# Epoch [6/100], Step [6410/10000], Train Loss: 0.4625, Train Acc: 0.7849
# Epoch [6/100], Step [6510/10000], Train Loss: 0.4624, Train Acc: 0.7848
# Epoch [6/100], Step [6610/10000], Train Loss: 0.4624, Train Acc: 0.7848
# Epoch [6/100], Step [6710/10000], Train Loss: 0.4624, Train Acc: 0.7848
# Epoch [6/100], Step [6810/10000], Train Loss: 0.4626, Train Acc: 0.7847
# Epoch [6/100], Step [6910/10000], Train Loss: 0.4626, Train Acc: 0.7847
# Epoch [6/100], Step [7010/10000], Train Loss: 0.4626, Train Acc: 0.7848
# Epoch [6/100], Step [7110/10000], Train Loss: 0.4627, Train Acc: 0.7846
# Epoch [6/100], Step
# Epoch [7/100], Step [5110/10000], Train Loss: 0.4600, Train Acc: 0.7863
# Epoch [7/100], Step [5210/10000], Train Loss: 0.4601, Train Acc: 0.7862
# Epoch [7/100], Step [5310/10000], Train Loss: 0.4602, Train Acc: 0.7861
# Epoch [7/100], Step [5410/10000], Train Loss: 0.4602, Train Acc: 0.7861
# Epoch [7/100], Step [5510/10000], Train Loss: 0.4599, Train Acc: 0.7863
# Epoch [7/100], Step [5610/10000], Train Loss: 0.4601, Train Acc: 0.7862
# Epoch [7/100], Step [5710/10000], Train Loss: 0.4603, Train Acc: 0.7861
# Epoch [7/100], Step [5810/10000], Train Loss: 0.4602, Train Acc: 0.7862
# ...
# Epoch [14/100], Step [7810/10000], Train Loss: 0.4609, Train Acc: 0.7871
# Epoch [14/100], Step [7910/10000], Train Loss: 0.4609, Train Acc: 0.7872
# Epoch [14/100], Step [8010/10000], Train Loss: 0.4610, Train Acc: 0.7871
# Epoch [14/100], Step [8110/10000], Train Loss: 0.4611, Train Acc: 0.7871
# Epoch [14/100], Step [8210/10000], Train Loss: 0.4610, Train Acc: 0.7871
# Epoch [14/100], Step [8310/10000], Train Loss: 0.4609, Train Acc: 0.7871
# Epoch [14/100], Step [8410/10000], Train Loss: 0.4609, Train Acc: 0.7871
# Epoch [14/100], Step [8510/10000], Train Loss: 0.4609, Train Acc: 0.7872
# Epoch [14/100], Step [8610/10000], Train Loss: 0.4609, Train Acc: 0.7872
# Epoch [14/100], Step [8710/10000], Train Loss: 0.4608, Train Acc: 0.7872
# Epoch [14/100], Step [8810/10000], Train Loss: 0.4608, Train Acc: 0.7873
# Epoch [14/100], Step [8910/10000], Train Loss: 0.4608, Train Acc: 0.7872
# Epoch [14/100], Step [9010/10000], Train Loss: 0.4607, Train Acc: 0.7873
# Epoch [14/100], Step [9110/10000], Train Loss: 0.4607, Train Acc: 0.7873
# Epoch [14/100], Step [9210/10000], Train Loss: 0.4607, Train Acc: 0.7873
# Epoch [14/100], Step [9310/10000], Train Loss: 0.4607, Train Acc: 0.7873
# Epoch [14/100], Step [9410/10000], Train Loss: 0.4607, Train Acc: 0.7873
# Epoch [14/100], Step [9510/10000], Train Loss: 0.4606, Train Acc: 0.7873
# Epoch [14/100], Step [9610/10000], Train Loss: 0.4606, Train Acc: 0.7873
# Epoch [14/100], Step [9710/10000], Train Loss: 0.4606, Train Acc: 0.7873
# Epoch [14/100], Step [9810/10000], Train Loss: 0.4606, Train Acc: 0.7873
# Epoch [14/100], Step [9910/10000], Train Loss: 0.4607, Train Acc: 0.7873
# Epoch [14/100], Val Loss: 0.4844, Val Acc: 0.7721, Precision: 0.7722, Recall: 0.7721, F1: 0.7721
# Epoch [15/100], Step [10/10000], Train Loss: 0.4776, Train Acc: 0.7742
# Epoch [15/100], Step [110/10000], Train Loss: 0.4530, Train Acc: 0.7971
# Epoch [15/100], Step [210/10000], Train Loss: 0.4592, Train Acc: 0.7917
# Epoch [15/100], Step [310/10000], Train Loss: 0.4581, Train Acc: 0.7918
# Epoch [15/100], Step [410/10000], Train Loss: 0.4580, Train Acc: 0.7910
# Epoch [15/100], Step [510/10000], Train Loss: 0.4579, Train Acc: 0.7915
# Epoch [15/100], Step [610/10000], Train Loss: 0.4582, Train Acc: 0.7906
# Epoch [15/100], Step [710/10000], Train Loss: 0.4578, Train Acc: 0.7909
# Epoch [15/100], Step [810/10000], Train Loss: 0.4579, Train Acc: 0.7902
# Epoch [15/100], Step [910/10000], Train Loss: 0.4586, Train Acc: 0.7900
# Epoch [15/100], Step [1010/10000], Train Loss: 0.4584, Train Acc: 0.7898
# Epoch [15/100], Step [1110/10000], Train Loss: 0.4591, Train Acc: 0.7894
# Epoch [15/100], Step [1210/10000], Train Loss: 0.4594, Train Acc: 0.7895
# Epoch [15/100], Step [1310/10000], Train Loss: 0.4594, Train Acc: 0.7892
# Epoch [15/100], Step [1410/10000], Train Loss: 0.4588, Train Acc: 0.7896
# Epoch [15/100], Step [1510/10000], Train Loss: 0.4590, Train Acc: 0.7895
# Epoch [15/100], Step [1610/10000], Train Loss: 0.4585, Train Acc: 0.7898
# Epoch [15/100], Step [1710/10000], Train Loss: 0.4584, Train Acc: 0.7901
# Epoch [15/100], Step [1810/10000], Train Loss: 0.4586, Train Acc: 0.7900
# Epoch [15/100], Step [1910/10000], Train Loss: 0.4583, Train Acc: 0.7903
# Epoch [15/100], Step [2010/10000], Train Loss: 0.4584, Train Acc: 0.7901
# Epoch [15/100], Step [2110/10000], Train Loss: 0.4585, Train Acc: 0.7900
# Epoch [15/100], Step [2210/10000], Train Loss: 0.4583, Train Acc: 0.7900
# Epoch [15/100], Step [2310/10000], Train Loss: 0.4588, Train Acc: 0.7896
# Epoch [15/100], Step [2410/10000], Train Loss: 0.4586, Train Acc: 0.7897
# Epoch [15/100], Step [2510/10000], Train Loss: 0.4583, Train Acc: 0.7899
# Epoch [15/100], Step [2610/10000], Train Loss: 0.4583, Train Acc: 0.7899
# Epoch [15/100], Step [2710/10000], Train Loss: 0.4584, Train Acc: 0.7899
# Epoch [15/100], Step [2810/10000], Train Loss: 0.4585, Train Acc: 0.7899
# Epoch [15/100], Step [2910/10000], Train Loss: 0.4587, Train Acc: 0.7898
# Epoch [15/100], Step [3010/10000], Train Loss: 0.4584, Train Acc: 0.7900
# Epoch [15/100], Step [3110/10000], Train Loss: 0.4583, Train Acc: 0.7900
# Epoch [15/100], Step [3210/10000], Train Loss: 0.4585, Train Acc: 0.7899
# Epoch [15/100], Step [3310/10000], Train Loss: 0.4585, Train Acc: 0.7898
# Epoch [15/100], Step [3410/10000], Train Loss: 0.4584, Train Acc: 0.7897
# Epoch [15/100], Step [3510/10000], Train Loss: 0.4585, Train Acc: 0.7897
# Epoch [15/100], Step [3610/10000], Train Loss: 0.4584, Train Acc: 0.7897
# Epoch [15/100], Step [3710/10000], Train Loss: 0.4585, Train Acc: 0.7896
# Epoch [15/100], Step [3810/10000], Train Loss: 0.4586, Train Acc: 0.7895
# Epoch [15/100], Step [3910/10000], Train Loss: 0.4587, Train Acc: 0.7893
# Epoch [15/100], Step [4010/10000], Train Loss: 0.4588, Train Acc: 0.7892
# Epoch [15/100], Step [4110/10000], Train Loss: 0.4590, Train Acc: 0.7891
# Epoch [15/100], Step [4210/10000], Train Loss: 0.4588, Train Acc: 0.7893
# Epoch [15/100], Step [4310/10000], Train Loss: 0.4588, Train Acc: 0.7893
# Epoch [15/100], Step [4410/10000], Train Loss: 0.4590, Train Acc: 0.7891
# Epoch [15/100], Step [4510/10000], Train Loss: 0.4590, Train Acc: 0.7891
# Epoch [15/100], Step [4610/10000], Train Loss: 0.4589, Train Acc: 0.7892
# Epoch [15/100], Step [4710/10000], Train Loss: 0.4589, Train Acc: 0.7892
# Epoch [15/100], Step [4810/10000], Train Loss: 0.4589, Train Acc: 0.7891
# Epoch [15/100], Step [4910/10000], Train Loss: 0.4589, Train Acc: 0.7890
# Epoch [15/100], Step [5010/10000], Train Loss: 0.4588, Train Acc: 0.7891
# Epoch [15/100], Step [5110/10000], Train Loss: 0.4589, Train Acc: 0.7891
# Epoch [15/100], Step [5210/10000], Train Loss: 0.4588, Train Acc: 0.7892
# Epoch [15/100], Step [5310/10000], Train Loss: 0.4587, Train Acc: 0.7892
# Epoch [15/100], Step [5410/10000], Train Loss: 0.4589, Train Acc: 0.7890
# Epoch [15/100], Step [5510/10000], Train Loss: 0.4588, Train Acc: 0.7891
# Epoch [15/100], Step [5610/10000], Train Loss: 0.4587, Train Acc: 0.7891
# Epoch [15/100], Step [5710/10000], Train Loss: 0.4587, Train Acc: 0.7891
# Epoch [15/100], Step [5810/10000], Train Loss: 0.4587, Train Acc: 0.7892
# Epoch [15/100], Step [5910/10000], Train Loss: 0.4587, Train Acc: 0.7892
# Epoch [15/100], Step [6010/10000], Train Loss: 0.4588, Train Acc: 0.7891
# Epoch [15/100], Step [6110/10000], Train Loss: 0.4587, Train Acc: 0.7892
# Epoch [15/100], Step [6210/10000], Train Loss: 0.4588, Train Acc: 0.7891
# Epoch [15/100], Step [6310/10000], Train Loss: 0.4589, Train Acc: 0.7891
# Epoch [15/100], Step [6410/10000], Train Loss: 0.4590, Train Acc: 0.7891
# Epoch [15/100], Step [6510/10000], Train Loss: 0.4590, Train Acc: 0.7891
# Epoch [15/100], Step [6610/10000], Train Loss: 0.4590, Train Acc: 0.7891
# Epoch [15/100], Step [6710/10000], Train Loss: 0.4591, Train Acc: 0.7891
# Epoch [15/100], Step [6810/10000], Train Loss: 0.4592, Train Acc: 0.7890
# Epoch [15/100], Step [6910/10000], Train Loss: 0.4591, Train Acc: 0.7889
# Epoch [15/100], Step [7010/10000], Train Loss: 0.4591, Train Acc: 0.7890
# Epoch [15/100], Step [7110/10000], Train Loss: 0.4591, Train Acc: 0.7889
# Epoch [15/100], Step [7210/10000], Train Loss: 0.4590, Train Acc: 0.7889
# Epoch [15/100], Step [7310/10000], Train Loss: 0.4590, Train Acc: 0.7889
# Epoch [15/100], Step [7410/10000], Train Loss: 0.4591, Train Acc: 0.7889
# Epoch [15/100], Step [7510/10000], Train Loss: 0.4591, Train Acc: 0.7888
# Epoch [15/100], Step [7610/10000], Train Loss: 0.4591, Train Acc: 0.7888
# Epoch [15/100], Step [7710/10000], Train Loss: 0.4591, Train Acc: 0.7888
# Epoch [15/100], Step [7810/10000], Train Loss: 0.4592, Train Acc: 0.7887
# Epoch [15/100], Step [7910/10000], Train Loss: 0.4592, Train Acc: 0.7888
# Epoch [15/100], Step [8010/10000], Train Loss: 0.4592, Train Acc: 0.7887
# Epoch [15/100], Step [8110/10000], Train Loss: 0.4592, Train Acc: 0.7887
# Epoch [15/100], Step [8210/10000], Train Loss: 0.4592, Train Acc: 0.7887
# Epoch [15/100], Step [8310/10000], Train Loss: 0.4593, Train Acc: 0.7886
# Epoch [15/100], Step [8410/10000], Train Loss: 0.4594, Train Acc: 0.7886
# Epoch [15/100], Step [8510/10000], Train Loss: 0.4595, Train Acc: 0.7886
# Epoch [15/100], Step [8610/10000], Train Loss: 0.4595, Train Acc: 0.7885
# Epoch [15/100], Step [8710/10000], Train Loss: 0.4596, Train Acc: 0.7885
# Epoch [15/100], Step [8810/10000], Train Loss: 0.4595, Train Acc: 0.7885
# Epoch [15/100], Step [8910/10000], Train Loss: 0.4597, Train Acc: 0.7884
# Epoch [15/100], Step [9010/10000], Train Loss: 0.4598, Train Acc: 0.7884
# Epoch [15/100], Step [9110/10000], Train Loss: 0.4599, Train Acc: 0.7884
# Epoch [15/100], Step [9210/10000], Train Loss: 0.4600, Train Acc: 0.7883
# Epoch [15/100], Step [9310/10000], Train Loss: 0.4600, Train Acc: 0.7883
# Epoch [15/100], Step [9410/10000], Train Loss: 0.4599, Train Acc: 0.7884
# Epoch [15/100], Step [9510/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [15/100], Step [9610/10000], Train Loss: 0.4601, Train Acc: 0.7884
# Epoch [15/100], Step [9710/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [15/100], Step [9810/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [15/100], Step [9910/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [15/100], Val Loss: 0.4864, Val Acc: 0.7704, Precision: 0.7729, Recall: 0.7704, F1: 0.7699
# Epoch [16/100], Step [10/10000], Train Loss: 0.4479, Train Acc: 0.7977
# Epoch [16/100], Step [110/10000], Train Loss: 0.4587, Train Acc: 0.7892
# Epoch [16/100], Step [210/10000], Train Loss: 0.4600, Train Acc: 0.7882
# Epoch [16/100], Step [310/10000], Train Loss: 0.4596, Train Acc: 0.7892
# Epoch [16/100], Step [410/10000], Train Loss: 0.4587, Train Acc: 0.7894
# Epoch [16/100], Step [510/10000], Train Loss: 0.4589, Train Acc: 0.7892
# Epoch [16/100], Step [610/10000], Train Loss: 0.4595, Train Acc: 0.7884
# Epoch [16/100], Step [710/10000], Train Loss: 0.4598, Train Acc: 0.7881
# Epoch [16/100], Step [810/10000], Train Loss: 0.4603, Train Acc: 0.7878
# Epoch [16/100], Step [910/10000], Train Loss: 0.4595, Train Acc: 0.7889
# Epoch [16/100], Step [1010/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [1110/10000], Train Loss: 0.4604, Train Acc: 0.7887
# Epoch [16/100], Step [1210/10000], Train Loss: 0.4602, Train Acc: 0.7888
# Epoch [16/100], Step [1310/10000], Train Loss: 0.4609, Train Acc: 0.7886
# Epoch [16/100], Step [1410/10000], Train Loss: 0.4612, Train Acc: 0.7882
# Epoch [16/100], Step [1510/10000], Train Loss: 0.4610, Train Acc: 0.7885
# Epoch [16/100], Step [1610/10000], Train Loss: 0.4608, Train Acc: 0.7884
# Epoch [16/100], Step [1710/10000], Train Loss: 0.4605, Train Acc: 0.7887
# Epoch [16/100], Step [1810/10000], Train Loss: 0.4605, Train Acc: 0.7886
# Epoch [16/100], Step [1910/10000], Train Loss: 0.4606, Train Acc: 0.7886
# Epoch [16/100], Step [2010/10000], Train Loss: 0.4602, Train Acc: 0.7887
# Epoch [16/100], Step [2110/10000], Train Loss: 0.4601, Train Acc: 0.7887
# Epoch [16/100], Step [2210/10000], Train Loss: 0.4602, Train Acc: 0.7887
# Epoch [16/100], Step [2310/10000], Train Loss: 0.4600, Train Acc: 0.7888
# Epoch [16/100], Step [2410/10000], Train Loss: 0.4600, Train Acc: 0.7888
# Epoch [16/100], Step [2510/10000], Train Loss: 0.4600, Train Acc: 0.7887
# Epoch [16/100], Step [2610/10000], Train Loss: 0.4599, Train Acc: 0.7887
# Epoch [16/100], Step [2710/10000], Train Loss: 0.4597, Train Acc: 0.7888
# Epoch [16/100], Step [2810/10000], Train Loss: 0.4596, Train Acc: 0.7889
# Epoch [16/100], Step [2910/10000], Train Loss: 0.4598, Train Acc: 0.7889
# Epoch [16/100], Step [3010/10000], Train Loss: 0.4598, Train Acc: 0.7888
# Epoch [16/100], Step [3110/10000], Train Loss: 0.4596, Train Acc: 0.7890
# Epoch [16/100], Step [3210/10000], Train Loss: 0.4598, Train Acc: 0.7888
# Epoch [16/100], Step [3310/10000], Train Loss: 0.4598, Train Acc: 0.7888
# Epoch [16/100], Step [3410/10000], Train Loss: 0.4600, Train Acc: 0.7888
# Epoch [16/100], Step [3510/10000], Train Loss: 0.4599, Train Acc: 0.7890
# Epoch [16/100], Step [3610/10000], Train Loss: 0.4601, Train Acc: 0.7889
# Epoch [16/100], Step [3710/10000], Train Loss: 0.4602, Train Acc: 0.7889
# Epoch [16/100], Step [3810/10000], Train Loss: 0.4598, Train Acc: 0.7890
# Epoch [16/100], Step [3910/10000], Train Loss: 0.4599, Train Acc: 0.7889
# Epoch [16/100], Step [4010/10000], Train Loss: 0.4600, Train Acc: 0.7888
# Epoch [16/100], Step [4110/10000], Train Loss: 0.4600, Train Acc: 0.7888
# Epoch [16/100], Step [4210/10000], Train Loss: 0.4601, Train Acc: 0.7887
# Epoch [16/100], Step [4310/10000], Train Loss: 0.4603, Train Acc: 0.7886
# Epoch [16/100], Step [4410/10000], Train Loss: 0.4602, Train Acc: 0.7886
# Epoch [16/100], Step [4510/10000], Train Loss: 0.4603, Train Acc: 0.7886
# Epoch [16/100], Step [4610/10000], Train Loss: 0.4603, Train Acc: 0.7886
# Epoch [16/100], Step [4710/10000], Train Loss: 0.4602, Train Acc: 0.7886
# Epoch [16/100], Step [4810/10000], Train Loss: 0.4600, Train Acc: 0.7886
# Epoch [16/100], Step [4910/10000], Train Loss: 0.4601, Train Acc: 0.7886
# Epoch [16/100], Step [5010/10000], Train Loss: 0.4603, Train Acc: 0.7885
# Epoch [16/100], Step [5110/10000], Train Loss: 0.4603, Train Acc: 0.7884
# Epoch [16/100], Step [5210/10000], Train Loss: 0.4602, Train Acc: 0.7885
# Epoch [16/100], Step [5310/10000], Train Loss: 0.4601, Train Acc: 0.7886
# Epoch [16/100], Step [5410/10000], Train Loss: 0.4601, Train Acc: 0.7885
# Epoch [16/100], Step [5510/10000], Train Loss: 0.4604, Train Acc: 0.7883
# Epoch [16/100], Step [5610/10000], Train Loss: 0.4604, Train Acc: 0.7883
# Epoch [16/100], Step [5710/10000], Train Loss: 0.4604, Train Acc: 0.7882
# Epoch [16/100], Step [5810/10000], Train Loss: 0.4603, Train Acc: 0.7882
# Epoch [16/100], Step [5910/10000], Train Loss: 0.4602, Train Acc: 0.7883
# Epoch [16/100], Step [6010/10000], Train Loss: 0.4601, Train Acc: 0.7884
# Epoch [16/100], Step [6110/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [16/100], Step [6210/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [16/100], Step [6310/10000], Train Loss: 0.4600, Train Acc: 0.7884
# Epoch [16/100], Step [6410/10000], Train Loss: 0.4599, Train Acc: 0.7885
# Epoch [16/100], Step [6510/10000], Train Loss: 0.4599, Train Acc: 0.7885
# Epoch [16/100], Step [6610/10000], Train Loss: 0.4599, Train Acc: 0.7885
# Epoch [16/100], Step [6710/10000], Train Loss: 0.4599, Train Acc: 0.7886
# Epoch [16/100], Step [6810/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [6910/10000], Train Loss: 0.4600, Train Acc: 0.7885
# Epoch [16/100], Step [7010/10000], Train Loss: 0.4600, Train Acc: 0.7885
# Epoch [16/100], Step [7110/10000], Train Loss: 0.4601, Train Acc: 0.7884
# Epoch [16/100], Step [7210/10000], Train Loss: 0.4600, Train Acc: 0.7885
# Epoch [16/100], Step [7310/10000], Train Loss: 0.4599, Train Acc: 0.7885
# Epoch [16/100], Step [7410/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [7510/10000], Train Loss: 0.4596, Train Acc: 0.7887
# Epoch [16/100], Step [7610/10000], Train Loss: 0.4597, Train Acc: 0.7886
# Epoch [16/100], Step [7710/10000], Train Loss: 0.4597, Train Acc: 0.7886
# Epoch [16/100], Step [7810/10000], Train Loss: 0.4597, Train Acc: 0.7886
# Epoch [16/100], Step [7910/10000], Train Loss: 0.4597, Train Acc: 0.7886
# Epoch [16/100], Step [8010/10000], Train Loss: 0.4597, Train Acc: 0.7886
# Epoch [16/100], Step [8110/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [8210/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [8310/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [8410/10000], Train Loss: 0.4597, Train Acc: 0.7887
# Epoch [16/100], Step [8510/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [8610/10000], Train Loss: 0.4597, Train Acc: 0.7886
# Epoch [16/100], Step [8710/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [8810/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [8910/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [9010/10000], Train Loss: 0.4598, Train Acc: 0.7886
# Epoch [16/100], Step [9110/10000], Train Loss: 0.4599, Train Acc: 0.7886
# Epoch [16/100], Step [9210/10000], Train Loss: 0.4600, Train Acc: 0.7885
# Epoch [16/100], Step [9310/10000], Train Loss: 0.4600, Train Acc: 0.7885
